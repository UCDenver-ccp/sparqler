# %%
# %%javascript
# function loadCSS(filename){
#
#        var file = document.createElement("link");
#        file.setAttribute("rel", "stylesheet");
#        file.setAttribute("type", "text/css");
#        file.setAttribute("href", filename);
#        document.head.appendChild(file);
#
# }
#
# //just call a function to load a new CSS:
# loadCSS("http://cdn.jsdelivr.net/yasqe/2.11.6/yasqe.min.css");
# loadCSS("http://yasr.yasgui.org/dist/yasr.min.css");
# loadCSS("http://yasr.yasgui.org/doc/doc.min.css");

# %%
# %%html
# <div id="yasqe" style="width: auto"></div>
# <div id="yasr" style="width: auto"></div>

# %%
# %%javascript
# var yasqe = YASQE(document.getElementById("yasqe"), {
# 	sparql: {
# 		showQueryButton: true,
# 		endpoint: "http://amc-tantor.ucdenver.pvt:10035/repositories/kabob-dev/",
# 		headers: {
# 			Authorization: 'secret:secret'
# 		},
# 		xhrFields: {
# 			withCredentials: true
# 		}
# 	}
# });
# var yasr = YASR(document.getElementById("yasr"), {
# 	//this way, the URLs in the results are prettified using the defined prefixes in the query
# 	getUsedPrefixes: yasqe.getPrefixesFromQuery
# });
#
#
# var j = '{"head":{"vars":["s", "p", "c"]},"results":{"bindings":[ {"s":{"type":"uri","value":"http://kabob.ucdenver.edu/iao/chebi/CHEBI_17303_ICE"},"p":{"type":"uri","value":"http://purl.obolibrary.org/obo/IAO_0000219"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x701751"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x701754"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x701762"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x724905"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x724909"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x724921"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x889694"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x889698"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x889708"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x889716"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x889719"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x889728"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x890540"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x890544"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x890551"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x938913"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x938918"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x938920"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1006810"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1034059"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079088"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079091"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079092"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079094"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079098"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079104"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079106"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079107"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079109"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079111"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079112"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079113"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079115"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079117"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079120"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079124"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079125"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079128"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079131"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079133"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079136"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079142"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079146"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079148"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079151"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079154"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079157"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079159"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079161"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079164"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079167"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079170"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079171"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079173"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079176"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079178"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079180"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079183"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079188"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079192"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079194"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1079197"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#annotatedSource"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1156238"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1277817"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1739053"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1815183"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1844832"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x1887023"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}},{"s":{"type":"bnode","value":"bC23AB735x2175211"},"p":{"type":"uri","value":"http://www.w3.org/2002/07/owl#someValuesFrom"},"c":{"type":"uri","value":"http://purl.obolibrary.org/obo/CHEBI_17303"}}]}}';
#
# yasr.setResponse(j);
#
# yasqe.options.sparql.callbacks.complete = yasr.setResponse;

# %%
# %%javascript
