# %%
# %%html
# <div class="col-md-2">
#   <h2>Documentation</h2>
#   <ul>
#     <li><a href="file:///Users/dcmcshan/Documents/KaBOB/sparqler/target/base+system+user+dev/doc/sparqler.terms.html">Terms</a></li>
#     <li><a href="file:///Users/dcmcshan/Documents/KaBOB/sparqler/target/base+system+user+dev/doc/sparqler.forms.html">Forms</a></li>
#     <li><a href="file:///Users/dcmcshan/Documents/KaBOB/sparqler/target/base+system+user+dev/doc/sparqler.queries.html">Queries</a></li>
#   </ul>
# </div>
# <div class="col-md-3">
#   <h2>Drug Queries</h2>
#   <ul>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Farsenic.bkr">Arsenic</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fdrugdrug.bkr">Drug Drug Interactions</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fdrugbankice.bkr">Drugbank ICE</a></li>
#   </ul>
#   <h2>GO Queries</h2>
#   <ul>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fcyccytosol.bkr">CYC Cytosol</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fcompartment.bkr">Compartment</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Flocalization.bkr">Localization</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fbiologicalprocess.bkr">Biological Process</a></li>
#   </ul>
#   <h2>Reactome Queries</h2>
#   <ul>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fentrez-reactome.bkr">Entrez Reactome</a></li>
#   </ul>
#   <h2>Uniprot Queries</h2>
#   <ul>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fhumangenes.bkr">Human Genes</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fhumanmousehomolog.bkr">Human Mouse Homologs</a></li>
#   </ul>
# </div>
# <div class="col-md-4">
# </div>
# <div class="col-md-5">
#   <h2>Data Sources</h2>
#   <ul>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fdatasets.bkr">Data Sets</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2Fontologies.bkr">Ontologies</a></li>
#   </ul>
# </div>
# <div class="col-md-6">
#   <h2>KaBOB Queries</h2>
#   <ul>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2FKaBOBC1.bkr">C1</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2FKaBOBC2.bkr">C2</a></li>
#     <li><a href="/beakerx/#/open?uri=file:%2FUsers%2Fdcmcshan%2FDocuments%2FKaBOB%2Fbeakertest%2FKaBOBC3.bkr">C3</a></li>
#   </ul>
# </div>
# <div class="row">
#   <div class="col-md-12" style="border-top: solid 1px #888; margin-top: 20px;">
#   </div>
# </div>
# <div class="row">
#   <div class="col-md-5">
#
#     <h2>Navigation</h2>
#     <p>
#       Clicking one of the links to the tutorials on the right navigates
#       your web browser to the that notebook.
#       You can use the browser's "Back" button to return to this page, or use
#       the <strong>Help → Tutorial</strong> menu again.
#     </p>
#     <p>
#       This tutorial is itself a notebook.  For example, this section is an
#       HTML cell, and you can show its input code by clicking the expanding arrows
#       icon in the row in the upper-right corner of the cell.
#     </p>
#   </div>
#   <div class="col-md-6">
#
#     <h2>Learn More</h2>
#     <p>
#       On the web at the homepage <a href="http://beakernotebook.com">BeakerNotebook.com</a>,
#       on the <a href="https://pub.beakernotebook.com">publication server</a>
#       for tutorials and community contributions,
#       and in <a href="https://lab.beakernotebook.com">Beaker Lab</a>, the free cloud-hosted version.
#     </p>
#
#     <h2>Open Source</h2>
#     <p>
#       Beaker's full source code and documentation are available on
#       <a href="https://github.com/twosigma/beakerx-notebook">GitHub</a> under the Apache 2.0 license.
#     </p>
#     <p>
#       We welcome your feedback, as it guides development and helps us improve.
#       Please feel free use the <strong>Help → Report a bug or feature request</strong> menu item.
#     </p>
#   </div>
# </div>

# %%
# %%html
